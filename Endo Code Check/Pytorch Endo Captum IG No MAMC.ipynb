# %%
# import libraries
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.autograd import grad

import matplotlib.pyplot as plt

from captum.attr import IntegratedGradients
from captum.attr import LayerConductance
from captum.attr import NeuronConductance

# %%
# import and login Weights and Baises
import wandb
# !wandb login
# Out:
# wandb: Currently logged in as: adisiddharth (use `wandb login --relogin` to force relogin)

# %%
# Initialize wandb project
wandb.init(project = 'Captum Pytorch')
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: adisiddharth (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.19 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/adisiddharth/Captum%20Pytorch/runs/1s6crm9v" target="_blank">earthy-breeze-135</a></strong> to <a href="https://wandb.ai/adisiddharth/Captum%20Pytorch" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/adisiddharth/Captum%20Pytorch/runs/1s6crm9v?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
# Pre-process train dataset
train = pd.read_csv('Endometriosis_subset_train_feature_extract_no_mamc_splitfunction_SUBSET.csv')

# Set index to IDs
train.set_axis(train['meth_id'], inplace = True)

# Drop the ID cols 
cols_drop = ['meth_id', 'meth_id.1']
train.drop(columns=cols_drop, inplace = True)

# Change Endo Yes/No to binary
train['Endometriosis_int'] = np.where(train['Endometriosis'] == 'Yes', 1, train['Endometriosis'])
train['Endometriosis_int'] = np.where(train['Endometriosis_int'] == 'No', 0, train['Endometriosis_int'])

train.drop(train.loc[train['Stage'] == 'UNKNOWN'].index, inplace=True)

# Comment out to remove Cycle Phase from features
train = train.join(pd.get_dummies(train['Cycle_Phase']))
y_train = train.pop('Endometriosis_int')
x_train = train.iloc[:, 5:-3]

# %%
# read val dataset
val = pd.read_csv('Endometriosis_subset_val_feature_extract_no_mamc_splitfunction_SUBSET.csv')

#set index to IDs
val = val.set_axis(val['meth_id'])

# Group ESE, MSE and LSE into SE 
val.loc[val['Cycle_Phase'].isin(['ESE', 'MSE', 'LSE']), 'Cycle_Phase'] = 'SE'

# Change Endo Yes/No to binary
val['Endometriosis_int'] = np.where(val['Endometriosis'] == 'Yes', 1, val['Endometriosis'])
val['Endometriosis_int'] = np.where(val['Endometriosis_int'] == 'No', 0, val['Endometriosis_int'])

val.drop(val.loc[val['Stage'] == 'UNKNOWN'].index, inplace=True)

# Comment out to remove Cycle Phase from features
val = val.join(pd.get_dummies(val['Cycle_Phase']))
y_val = val.pop('Endometriosis_int')
x_val = val.iloc[:, 7:-3]

# %%
# Pre-Process test set
test = pd.read_csv('Endometriosis_subset_test2_feature_extract_no_mamc_splitfunction_SUBSET.csv')

# Assign index as IDs
test.set_index('meth_id', inplace = True)

test.drop(test.loc[test['Stage'] == 'UNKNOWN'].index, inplace=True)

test.drop('Unnamed: 0', axis=1, inplace=True)

# Change Endo Yes/No to binary
test['Endometriosis_int'] = np.where(test['Endometriosis'] == 'Yes', 1, test['Endometriosis'])
test['Endometriosis_int'] = np.where(test['Endometriosis_int'] == 'No', 0, test['Endometriosis_int'])

# Comment out to remove Cycle Phase from features
#test = test.join(pd.get_dummies(test['Cycle_Phase']))
y_test = test.pop('Endometriosis_int')
x_test = test.iloc[:, 5:]

# %%
# Set train and test features and labels
train_features = x_train.to_numpy()
train_labels = y_train.to_numpy(dtype=np.int64)

val_features = x_val.to_numpy()
val_labels = y_val.to_numpy(dtype=np.int64)

test_features = x_test.to_numpy()
test_labels = y_test.to_numpy(dtype=np.int64)

# %%
train_features.shape, test_features.shape, val_features.shape, test_labels.shape, val_labels.shape, train_labels.shape
# Out:
# ((99, 94), (50, 94), (98, 94), (50,), (98,), (99,))

# %%
# Set hyperparameters
lr=0.0001 
optimizer = "Adamax"
num_epochs = 500
loss = 'CrossEntropyLoss'
nodes = 300
activation1 = 'relu'
activation2 = 'softmax'

# %%
# Set up config (columns) to record in wandb
run_config = {'lr': lr, 'optimizer': optimizer, 'epochs': num_epochs, 'nodes': nodes, 'activation1': activation1, 'activation2': activation2, 'loss': loss}
wandb_run = wandb.init(project='Captum Pytorch', config=run_config)
# Out:
# Finishing last run (ID:15ynfavc) before initializing another...
# <br/>Waiting for W&B process to finish, PID 62724... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# </div><div class="wandb-col">
# </div></div>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">easy-sound-136</strong>: <a href="https://wandb.ai/adisiddharth/Captum%20Pytorch/runs/15ynfavc" target="_blank">https://wandb.ai/adisiddharth/Captum%20Pytorch/runs/15ynfavc</a><br/>
# Find logs at: <code>./wandb/run-20220624_204709-15ynfavc/logs</code><br/>
# Successfully finished last run (ID:15ynfavc). Initializing new run:<br/>
# wandb: wandb version 0.12.19 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/adisiddharth/Captum%20Pytorch/runs/23gecpso" target="_blank">sunny-forest-137</a></strong> to <a href="https://wandb.ai/adisiddharth/Captum%20Pytorch" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>

# %%
if activation1 == 'relu':    
    activation1 = nn.ReLU()
elif activation1 == 'elu':    
    activation1 = nn.ELU()
elif activation1 == 'selu':    
    activation1 = nn.SELU()
elif activation1 == 'sigmoid':    
    activation1 = nn.Sigmoid()
if activation2 == 'sigmoid':    
    activation2 = nn.Sigmoid()
elif activation2 == 'relu':    
    activation2 = nn.ReLU()
elif activation2 == 'softmax':    
    activation2 = nn.Softmax()

# %%
# Model
class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear1 = nn.Linear(train_features.shape[1], nodes)
        self.relu1 = activation1
        self.linear2 = nn.Linear(nodes, nodes)
        self.relu2 = activation1
        self.linear3 = nn.Linear(nodes, nodes)
        self.relu3 = activation1
        self.linear4 = nn.Linear(nodes, nodes)
        self.relu4 = activation1
        self.linear5 = nn.Linear(nodes, nodes)
        self.relu5 = activation1
        self.linear6 = nn.Linear(nodes, nodes)
        self.relu6 = activation1
        self.linear7 = nn.Linear(nodes, nodes)
        self.relu7 = activation1
        self.linear8 = nn.Linear(nodes, nodes)
        self.relu8 = activation1
        self.linear9 = nn.Linear(nodes, nodes)
        self.relu9 = activation1
        self.linear10 = nn.Linear(nodes, 2)
        self.relu10 = activation2
        
    def forward(self, x):
        out1 = self.linear1(x)
        out2 = self.relu1(out1)
        out3 = self.relu2(self.linear2(out2))
        out4 = self.relu3(self.linear3(out3))
        out5 = self.relu4(self.linear4(out4))
        out6 = self.relu5(self.linear5(out5))
        out7 = self.relu6(self.linear6(out6))
        out8 = self.relu7(self.linear7(out7))
        out9 = self.relu8(self.linear8(out8))
        out10 = self.relu9(self.linear9(out9))
        out11 = self.relu10(self.linear10(out10))
        return out11

    
model = Model()

import numpy as np
min_valid_loss = np.inf

input_tensor = torch.from_numpy(train_features).type(torch.FloatTensor)
label_tensor = torch.from_numpy(train_labels)

val_input_tensor = torch.from_numpy(val_features).type(torch.FloatTensor)
val_label_tensor = torch.from_numpy(val_labels)
for e in range(num_epochs):
    train_loss = 0.0
    #model.train()     # Optional when not using Model Specific layer
    if loss == 'MAE':
        criterion = nn.L1Loss()
    elif loss == 'CrossEntropyLoss':    
        criterion = nn.CrossEntropyLoss()
    elif loss == 'MSE':    
        criterion = nn.MSELoss()
    elif loss == 'BCE':    
        criterion = nn.BCELoss()
    elif loss == 'BCEWithLogitsLoss':
        criterion = nn.BCEWithLogitsLoss
    if optimizer == 'Adam':
        optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    elif optimizer == 'Adamax':
        optimizer = torch.optim.Adamax(model.parameters(), lr=lr)
    elif optimizer == 'Adagrad':
        optimizer = torch.optim.Adagrad(model.parameters(), lr=lr)
    optimizer.zero_grad()
    target = model(input_tensor)
    loss = criterion(target, label_tensor)
    loss.backward()
    optimizer.step()
    train_loss += loss.item()
    
    valid_loss = 0.0
    model.eval()     # Optional when not using Model Specific layer


    target = model(val_input_tensor)
    loss = criterion(target,val_label_tensor)
    valid_loss = loss.item() * val_input_tensor.size(0)
    if e % 50 == 0:
        print(f'Epoch {e+1} \t\t Training Loss: {train_loss / len(val_input_tensor)} \t\t Validation Loss: {valid_loss / len(val_input_tensor)}')
    if min_valid_loss > valid_loss:
        print(f'Validation Loss Decreased({min_valid_loss:.6f}--->{valid_loss:.6f}) \t Saving The Model')
        min_valid_loss = valid_loss
        # Saving State Dict
        torch.save(model.state_dict(), 'saved_model.pth')

#input_tensor = torch.from_numpy(train_features).type(torch.FloatTensor)
test_input_tensor = torch.from_numpy(test_features).type(torch.FloatTensor)
# Out:
# <ipython-input-24-51d084ecc3c6>:37: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   out11 = self.relu10(self.linear10(out10))
# Epoch 1 		 Training Loss: 0.007081862615079296 		 Validation Loss: 0.6936399340629578
# Validation Loss Decreased(inf--->67.976714) 	 Saving The Model
# Validation Loss Decreased(67.976714--->67.941736) 	 Saving The Model
# Validation Loss Decreased(67.941736--->67.907863) 	 Saving The Model
# Validation Loss Decreased(67.907863--->67.875339) 	 Saving The Model
# Validation Loss Decreased(67.875339--->67.843404) 	 Saving The Model
# Validation Loss Decreased(67.843404--->67.812498) 	 Saving The Model
# Validation Loss Decreased(67.812498--->67.782013) 	 Saving The Model
# Validation Loss Decreased(67.782013--->67.752135) 	 Saving The Model
# Validation Loss Decreased(67.752135--->67.722689) 	 Saving The Model
# Validation Loss Decreased(67.722689--->67.693343) 	 Saving The Model
# Validation Loss Decreased(67.693343--->67.664201) 	 Saving The Model
# Validation Loss Decreased(67.664201--->67.635795) 	 Saving The Model
# Validation Loss Decreased(67.635795--->67.607523) 	 Saving The Model
# Validation Loss Decreased(67.607523--->67.579520) 	 Saving The Model
# Validation Loss Decreased(67.579520--->67.551558) 	 Saving The Model
# Validation Loss Decreased(67.551558--->67.523619) 	 Saving The Model
# Validation Loss Decreased(67.523619--->67.495692) 	 Saving The Model
# Validation Loss Decreased(67.495692--->67.467631) 	 Saving The Model
# Validation Loss Decreased(67.467631--->67.439084) 	 Saving The Model
# Validation Loss Decreased(67.439084--->67.410258) 	 Saving The Model
# Validation Loss Decreased(67.410258--->67.381163) 	 Saving The Model
# Validation Loss Decreased(67.381163--->67.351267) 	 Saving The Model
# Validation Loss Decreased(67.351267--->67.320688) 	 Saving The Model
# Validation Loss Decreased(67.320688--->67.289589) 	 Saving The Model
# Validation Loss Decreased(67.289589--->67.258268) 	 Saving The Model
# Validation Loss Decreased(67.258268--->67.227263) 	 Saving The Model
# Validation Loss Decreased(67.227263--->67.195784) 	 Saving The Model
# Validation Loss Decreased(67.195784--->67.163401) 	 Saving The Model
# Validation Loss Decreased(67.163401--->67.130608) 	 Saving The Model
# Validation Loss Decreased(67.130608--->67.097283) 	 Saving The Model
# Validation Loss Decreased(67.097283--->67.063036) 	 Saving The Model
# Validation Loss Decreased(67.063036--->67.027878) 	 Saving The Model
# Validation Loss Decreased(67.027878--->66.991288) 	 Saving The Model
# Validation Loss Decreased(66.991288--->66.953513) 	 Saving The Model
# Validation Loss Decreased(66.953513--->66.914505) 	 Saving The Model
# Validation Loss Decreased(66.914505--->66.874323) 	 Saving The Model
# Validation Loss Decreased(66.874323--->66.833481) 	 Saving The Model
# Validation Loss Decreased(66.833481--->66.792206) 	 Saving The Model
# Validation Loss Decreased(66.792206--->66.749331) 	 Saving The Model
# Validation Loss Decreased(66.749331--->66.704325) 	 Saving The Model
# Validation Loss Decreased(66.704325--->66.657279) 	 Saving The Model
# Validation Loss Decreased(66.657279--->66.608820) 	 Saving The Model
# Validation Loss Decreased(66.608820--->66.558953) 	 Saving The Model
# Validation Loss Decreased(66.558953--->66.507918) 	 Saving The Model
# Validation Loss Decreased(66.507918--->66.454383) 	 Saving The Model
# Validation Loss Decreased(66.454383--->66.398944) 	 Saving The Model
# Validation Loss Decreased(66.398944--->66.341781) 	 Saving The Model
# Validation Loss Decreased(66.341781--->66.283602) 	 Saving The Model
# Validation Loss Decreased(66.283602--->66.225838) 	 Saving The Model
# Validation Loss Decreased(66.225838--->66.169639) 	 Saving The Model
# Epoch 51 		 Training Loss: 0.006839738816631084 		 Validation Loss: 0.6746586561203003
# Validation Loss Decreased(66.169639--->66.116548) 	 Saving The Model
# Validation Loss Decreased(66.116548--->66.068171) 	 Saving The Model
# Validation Loss Decreased(66.068171--->66.026009) 	 Saving The Model
# Validation Loss Decreased(66.026009--->65.991183) 	 Saving The Model
# Validation Loss Decreased(65.991183--->65.963981) 	 Saving The Model
# Validation Loss Decreased(65.963981--->65.944190) 	 Saving The Model
# Validation Loss Decreased(65.944190--->65.930861) 	 Saving The Model
# Validation Loss Decreased(65.930861--->65.922881) 	 Saving The Model
# Validation Loss Decreased(65.922881--->65.919050) 	 Saving The Model
# Validation Loss Decreased(65.919050--->65.918647) 	 Saving The Model
# Epoch 101 		 Training Loss: 0.006796923827151863 		 Validation Loss: 0.6731732487678528
# Validation Loss Decreased(65.918647--->65.915679) 	 Saving The Model
# Validation Loss Decreased(65.915679--->65.912437) 	 Saving The Model
# Validation Loss Decreased(65.912437--->65.909318) 	 Saving The Model
# Validation Loss Decreased(65.909318--->65.906222) 	 Saving The Model
# Validation Loss Decreased(65.906222--->65.903243) 	 Saving The Model
# Validation Loss Decreased(65.903243--->65.900469) 	 Saving The Model
# Validation Loss Decreased(65.900469--->65.897974) 	 Saving The Model
# Validation Loss Decreased(65.897974--->65.895766) 	 Saving The Model
# Validation Loss Decreased(65.895766--->65.893926) 	 Saving The Model
# Validation Loss Decreased(65.893926--->65.892682) 	 Saving The Model
# Validation Loss Decreased(65.892682--->65.892127) 	 Saving The Model
# Epoch 151 		 Training Loss: 0.006414447511945452 		 Validation Loss: 0.6807042360305786
# Epoch 201 		 Training Loss: 0.005278865293580659 		 Validation Loss: 0.7112182974815369
# Epoch 251 		 Training Loss: 0.0047519331683917925 		 Validation Loss: 0.7112208604812622
# Epoch 301 		 Training Loss: 0.004297050894523154 		 Validation Loss: 0.7112208604812622
# Epoch 351 		 Training Loss: 0.0034111026598482716 		 Validation Loss: 0.7112208604812622
# Epoch 401 		 Training Loss: 0.003404454613218502 		 Validation Loss: 0.7112208604812622
# Epoch 451 		 Training Loss: 0.0033974282595576073 		 Validation Loss: 0.7112208604812622

# %%
out_probs_train = model(input_tensor).detach().numpy()
out_classes_train = np.argmax(out_probs_train, axis=1)
train_acc = sum(out_classes_train == train_labels) / len(train_labels)
print("Train Accuracy:", train_acc)
# Out:
# Train Accuracy: 0.98989898989899
# <ipython-input-24-51d084ecc3c6>:37: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   out11 = self.relu10(self.linear10(out10))

# %%
val_input_tensor = torch.from_numpy(val_features).type(torch.FloatTensor)
out_probs_val = model(val_input_tensor).detach().numpy()
out_classes_val = np.argmax(out_probs_val, axis=1)
val_acc = sum(out_classes_val == val_labels) / len(val_labels)
print("Val Accuracy:", val_acc)
# Out:
# Val Accuracy: 0.6020408163265306
# <ipython-input-24-51d084ecc3c6>:37: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   out11 = self.relu10(self.linear10(out10))

# %%
test_input_tensor = torch.from_numpy(test_features).type(torch.FloatTensor)
out_probs_test = model(test_input_tensor).detach().numpy()
out_classes_test = np.argmax(out_probs_test, axis=1)
test_acc = sum(out_classes_test == test_labels) / len(test_labels)
print("Test Accuracy:", test_acc)
# Out:
# Test Accuracy: 0.82
# <ipython-input-24-51d084ecc3c6>:37: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   out11 = self.relu10(self.linear10(out10))

# %%
from sklearn.metrics import roc_curve, roc_auc_score

r_probs = [0 for _ in range(len(y_test))]
test_labels = test_labels.astype('float32')

#Random chance ROC
r_auc = roc_auc_score(test_labels, r_probs)
r_fpr, r_tpr, _ = roc_curve(test_labels, r_probs)

#Train ROC
tr_fpr, tr_tpr, _ = roc_curve(train_labels, out_probs_train[:, 1])
tr_auc = roc_auc_score(train_labels, out_probs_train[:, 1])

#Val ROC
val_fpr, val_tpr, _ = roc_curve(val_labels, out_probs_val[:, 1])
val_auc = roc_auc_score(val_labels, out_probs_val[:, 1])

# External Test ROC
fpr, tpr, _ = roc_curve(test_labels, out_probs_test[:, 1])
auc = roc_auc_score(test_labels, out_probs_test[:, 1])

# %%
print('Random (chance) Prediction: AUROC = %.3f' % (r_auc))
print('Test Prediction: AUROC = %.3f' % (auc))
print('Train Prediction: AUROC = %.3f' % (tr_auc))
print('Val Prediction: AUROC = %.3f' % (val_auc))
# Out:
# Random (chance) Prediction: AUROC = 0.500
# Test Prediction: AUROC = 0.775
# Train Prediction: AUROC = 0.984
# Val Prediction: AUROC = 0.500

# %%
# AUC Plots
plt.plot(r_fpr, r_tpr, linestyle='--', label='Random prediction (AUROC = %0.3f)' % r_auc)
plt.plot(tr_fpr, tr_tpr, marker='.', label='Train (AUROC = %0.3f)' % tr_auc)
plt.plot(val_fpr, val_tpr, marker='.', label='Val (AUROC = %0.3f)' % val_auc)
plt.plot(fpr, tpr, marker='.', label='Test (AUROC = %0.3f)' % auc)

# Title
plt.title('ROC Plot')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# Show legend
plt.legend(loc = 'lower right', prop={'size': 10}) 
plt.tight_layout()
#plt.savefig(dataset + '_' + activation1 + '_' + activation2 + '_' + 'ROC_Curve' + kfold + '.png', bbox_inches = "tight")

# %%
# record more metrics in wandb
wandb_run.log({'auc': auc, 'train_accuracy': train_acc, 'test_accuracy': test_acc})

# %%
# set up integrated gradients 
ig = IntegratedGradients(model)

# %%
# obtain integrated gradient attributes
test_input_tensor.requires_grad_()
attr, delta = ig.attribute(test_input_tensor,target=1, return_convergence_delta=True)
attr = attr.detach().numpy()
# Out:
# <ipython-input-26-6500a9a0cb8e>:52: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   out11 = self.relu10(self.linear10(out10))

# %%
# get cpg islands
feature_names = x_train.columns

# %%
# Plot relative importance of cpg islands
attributes = pd.DataFrame()
cpg = []
imp = []
def visualize_importances(feature_names, importances, title="Average Feature Importances", plot=True, axis_title="Features"):
    #print(title)
    for i in range(len(feature_names)):
        #print(feature_names[i], ": ", '%.3f'%(importances[i]))
        cpg.append(feature_names[i])
        imp.append(importances[i])
    
    
    x_pos = (np.arange(len(feature_names)))
    if plot:
        plt.figure(figsize=(12,6))
        plt.bar(x_pos, importances, align='center')
        plt.xticks(x_pos, feature_names, wrap=True)
        plt.xlabel(axis_title)
        plt.title(title)
attributes['CPG'] = cpg
attributes['Attributes'] = imp
visualize_importances(feature_names, np.mean(attr, axis=0))

# %%
# collate data into dataframe
attributes['CPG'] = cpg
attributes['Attributes'] = imp
attributes['Attributes Abs'] = np.abs(attributes['Attributes']) # Absolute value of attributes

# Order df by descending absolute value of attributes
attributes = attributes.sort_values(by = ['Attributes Abs'], ascending = False)

at = attributes.reset_index()

# %%
plt.plot(np.abs(at['Attributes Abs'][:1000]))
plt.title('Integrated Gradients Attributes')
# Out:
# Text(0.5, 1.0, 'Integrated Gradients Attributes')

# %%
# Get top 500 CPG islands
cpg_captum = attributes.iloc[:500,0].to_list()

# %%
# write top 500 cpg islands to txt
with open('top_500_cpg_captum.txt', 'w') as f:
    for item in cpg_captum:
        f.write(item)
        f.write('\n')

# %%
# subset testing set CPG islands using top 500 CPG islands from IG 
top_500_cpg_df = x_test[x_test.columns.intersection(cpg_captum)]

# %%
# set up color map
color_list = ['r', 'b', 'g', 'y', 'k', 'm']
vals_1 = y_test.unique()
lut_1 = dict(zip(vals_1, ''.join(color_list[:len(vals_1)])))
row_colors_1 = y_test.map(lut_1).values

# %%
import seaborn as sns
g = sns.clustermap(top_500_cpg_df, standard_scale=1, row_colors=row_colors_1)
g.ax_heatmap.tick_params(right=False, bottom=False, labelbottom=False, labelright=False)
g.fig.suptitle("Pytorch Grouping extremes train, extreme visualize clustermap")
# Out:
# /home/ubuntu/anaconda3/envs/pytorch_env2/lib/python3.8/site-packages/seaborn/matrix.py:654: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# Text(0.5, 0.98, 'Pytorch Grouping extremes train, extreme visualize clustermap')
